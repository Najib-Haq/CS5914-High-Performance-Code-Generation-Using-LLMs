# %%
import pandas as pd

# %%
from glob import glob

folder_name = 'parallel_reduction1_benchmarks'
# files = glob(f'{folder_name}/**/*.txt')

sizes = [1024, 1000000, 1000000000, 2000000000]
file_names = [
    "output", "ncu_basic", "ncu_memory_usage", "ncu_warp_efficiency", "ncu_threaddiv"
]


# group files by a key function
def key_func(file, file_dict):
    key = int(file.split('/')[-2].split('_')[-1])
    if key not in file_dict:
        file_dict[key] = {}

    file_name = file.split('/')[-1].split('.')[0]
    if file_name in file_names:
        file_dict[key][file_name] = file

    return file_dict

# %%
# def contents of a file as a single string

def read_file_contents(file):
    with open(file, 'r') as f:
        return f.read()
    

# from the string, get the line which contains a text
def get_line_with_text(text, line):
    lines = text.split('\n')
    for l in lines:
        if line in l:
            return l
    return None

# %%
metric_names = [
    'cudaEventRecord', 'Duration', 'DRAM mem', 'L1 mem', 'Warp exec %', 'Warp avg threads', 'Mem thrpt', 'DRAM thrpt', 'L1 thrpt', 'L2 thrpt', 'SM Active Cycles', 'Occupancy', 'Branch eff'
    ]

def get_metrics(size_wise_files, size):
    metrics = {'Input Size': size}

    output_txt = read_file_contents(size_wise_files['output'])
    ncu_basic_txt = read_file_contents(size_wise_files['ncu_threaddiv'])
    ncu_memory_usage_txt = read_file_contents(size_wise_files['ncu_memory_usage'])
    ncu_warp_efficiency_txt = read_file_contents(size_wise_files['ncu_warp_efficiency'])
    ncu_threaddiv_txt = read_file_contents(size_wise_files['ncu_threaddiv'])

    
    metrics['cudaEventRecord'] = get_line_with_text(output_txt, 'Kernel Execution Time:').split(' ')[-2] 

    duration_out = get_line_with_text(ncu_basic_txt, 'Duration').split()
    metrics['Duration'] = duration_out[-1] + ' ' + duration_out[-2]

    mem_out = get_line_with_text(ncu_memory_usage_txt, 'dram__bytes_read.sum').split()
    metrics['DRAM mem'] = mem_out[-1] + ' ' + mem_out[-2]
    mem_out = get_line_with_text(ncu_memory_usage_txt, 'l1tex__t_bytes.sum').split()
    metrics['L1 mem'] = mem_out[-1] + ' ' + mem_out[-2]

    warp_out = get_line_with_text(ncu_warp_efficiency_txt, 'smsp__thread_inst_executed_per_inst_executed.pct').split()
    metrics['Warp exec %'] = warp_out[-1]
    warp_out = get_line_with_text(ncu_warp_efficiency_txt, 'smsp__thread_inst_executed_per_inst_executed.ratio').split()
    metrics['Warp avg threads'] = warp_out[-1]

    thrpt_out = get_line_with_text(ncu_threaddiv_txt, 'Memory Throughput').split()
    metrics['Mem thrpt'] = thrpt_out[-1]
    thrpt_out = get_line_with_text(ncu_threaddiv_txt, 'DRAM Throughput').split()
    metrics['DRAM thrpt'] = thrpt_out[-1]
    thrpt_out = get_line_with_text(ncu_threaddiv_txt, 'L1/TEX Cache Throughput').split()
    metrics['L1 thrpt'] = thrpt_out[-1]
    thrpt_out = get_line_with_text(ncu_threaddiv_txt, 'L2 Cache Throughput').split()
    metrics['L2 thrpt'] = thrpt_out[-1]

    sm_out = get_line_with_text(ncu_threaddiv_txt, 'Compute (SM) Throughput').split()
    metrics['SM Throughput'] = sm_out[-1]
    occupancy_out = get_line_with_text(ncu_threaddiv_txt, 'Achieved Occupancy').split()
    metrics['Occupancy'] = occupancy_out[-1]

    branch_out = get_line_with_text(ncu_threaddiv_txt, 'Branch Efficiency').split()
    metrics['Branch eff'] = branch_out[-1]

    print(metrics)

    return metrics

# %%
def get_folder_metrics(folder_name):
    method_name = '_'.join(folder_name.split('/')[-1].split('_')[:-1])
    files = glob(f'{folder_name}/**/*.txt')

    file_dict = {}
    for file in files:
        file_dict = key_func(file, file_dict)

    print("Files: ", file_dict)
    

    row = []
    for size in sizes:
        print(f"Size: {size}")
        size_wise_files = file_dict[size]
        metrics = get_metrics(size_wise_files, size)
        row.append(metrics)

    df = pd.DataFrame(row)
    df = df.set_index('Input Size')

    df.to_csv(f'output_metrics/{method_name}.csv')
    return df

# %%
glob('*benchmarks')
# Out:
# ['parallel_reduction4_benchmarks',
#  'parallel_reduction2a_benchmarks',
#  'parallel_reduction2b_benchmarks',
#  'parallel_reduction2_benchmarks',
#  'llm_based_gpt4o_mini_benchmarks',
#  'parallel_reduction3_benchmarks',
#  'parallel_reduction3a_benchmarks',
#  'parallel_reduction2c_benchmarks',
#  'parallel_reduction1_benchmarks',
#  'parallel_reduction3b_benchmarks']

# %%
folders = [
    'parallel_reduction1_benchmarks',
    'parallel_reduction2a_benchmarks',
    'parallel_reduction2b_benchmarks',
    'parallel_reduction2c_benchmarks',
    'parallel_reduction3a_benchmarks',
    'parallel_reduction3b_benchmarks',
    'parallel_reduction4_benchmarks',
    'llm_based_gpt4o_mini_benchmarks'
]

# %%
for folder in folders:
    print(f"Processing folder: {folder}")
    df = get_folder_metrics(folder)
    print(df)
    print("\n")
# Out:
# Processing folder: parallel_reduction1_benchmarks
# Files:  {1024: {'ncu_threaddiv': 'parallel_reduction1_benchmarks/parallel_reduction1_1024/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction1_benchmarks/parallel_reduction1_1024/ncu_basic.txt', 'output': 'parallel_reduction1_benchmarks/parallel_reduction1_1024/output.txt', 'ncu_memory_usage': 'parallel_reduction1_benchmarks/parallel_reduction1_1024/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction1_benchmarks/parallel_reduction1_1024/ncu_warp_efficiency.txt'}, 1000000000: {'ncu_threaddiv': 'parallel_reduction1_benchmarks/parallel_reduction1_1000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction1_benchmarks/parallel_reduction1_1000000000/ncu_basic.txt', 'output': 'parallel_reduction1_benchmarks/parallel_reduction1_1000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction1_benchmarks/parallel_reduction1_1000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction1_benchmarks/parallel_reduction1_1000000000/ncu_warp_efficiency.txt'}, 1000000: {'ncu_threaddiv': 'parallel_reduction1_benchmarks/parallel_reduction1_1000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction1_benchmarks/parallel_reduction1_1000000/ncu_basic.txt', 'output': 'parallel_reduction1_benchmarks/parallel_reduction1_1000000/output.txt', 'ncu_memory_usage': 'parallel_reduction1_benchmarks/parallel_reduction1_1000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction1_benchmarks/parallel_reduction1_1000000/ncu_warp_efficiency.txt'}, 2000000000: {'ncu_threaddiv': 'parallel_reduction1_benchmarks/parallel_reduction1_2000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction1_benchmarks/parallel_reduction1_2000000000/ncu_basic.txt', 'output': 'parallel_reduction1_benchmarks/parallel_reduction1_2000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction1_benchmarks/parallel_reduction1_2000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction1_benchmarks/parallel_reduction1_2000000000/ncu_warp_efficiency.txt'}}
# Size: 1024
# {'Input Size': 1024, 'cudaEventRecord': '36.0305', 'Duration': '7.74 usecond', 'DRAM mem': '7.81 Kbyte', 'L1 mem': '49.12 Kbyte', 'Warp exec %': '84.85', 'Warp avg threads': '27.15', 'Mem thrpt': '0.23', 'DRAM thrpt': '0.03', 'L1 thrpt': '16.08', 'L2 thrpt': '0.23', 'SM Throughput': '0.29', 'Occupancy': '49.15', 'Branch eff': '77.87'}
# Size: 1000000
# {'Input Size': 1000000, 'cudaEventRecord': '26.7265', 'Duration': '41.41 usecond', 'DRAM mem': '4.00 Mbyte', 'L1 mem': '47.97 Mbyte', 'Warp exec %': '84.85', 'Warp avg threads': '27.15', 'Mem thrpt': '20.00', 'DRAM thrpt': '4.74', 'L1 thrpt': '15.87', 'L2 thrpt': '23.70', 'SM Throughput': '51.28', 'Occupancy': '91.97', 'Branch eff': '77.87'}
# Size: 1000000000
# {'Input Size': 1000000000, 'cudaEventRecord': '56.8095', 'Duration': '34.12 msecond', 'DRAM mem': '4.00 Gbyte', 'L1 mem': '47.97 Gbyte', 'Warp exec %': '84.85', 'Warp avg threads': '27.15', 'Mem thrpt': '24.01', 'DRAM thrpt': '11.48', 'L1 thrpt': '16.64', 'L2 thrpt': '28.59', 'SM Throughput': '61.69', 'Occupancy': '95.96', 'Branch eff': '77.87'}
# Size: 2000000000
# {'Input Size': 2000000000, 'cudaEventRecord': '91.892', 'Duration': '68.23 msecond', 'DRAM mem': '8.00 Gbyte', 'L1 mem': '95.94 Gbyte', 'Warp exec %': '84.85', 'Warp avg threads': '27.15', 'Mem thrpt': '24.01', 'DRAM thrpt': '11.50', 'L1 thrpt': '16.64', 'L2 thrpt': '28.57', 'SM Throughput': '61.70', 'Occupancy': '95.97', 'Branch eff': '77.87'}
#            cudaEventRecord       Duration    DRAM mem       L1 mem  \
# Input Size
# 1024               36.0305   7.74 usecond  7.81 Kbyte  49.12 Kbyte
# 1000000            26.7265  41.41 usecond  4.00 Mbyte  47.97 Mbyte
# 1000000000         56.8095  34.12 msecond  4.00 Gbyte  47.97 Gbyte
# 2000000000          91.892  68.23 msecond  8.00 Gbyte  95.94 Gbyte
#
#            Warp exec % Warp avg threads Mem thrpt DRAM thrpt L1 thrpt  \
# Input Size
# 1024             84.85            27.15      0.23       0.03    16.08
# 1000000          84.85            27.15     20.00       4.74    15.87
# 1000000000       84.85            27.15     24.01      11.48    16.64
# 2000000000       84.85            27.15     24.01      11.50    16.64
#
#            L2 thrpt SM Throughput Occupancy Branch eff
# Input Size
# 1024           0.23          0.29     49.15      77.87
# 1000000       23.70         51.28     91.97      77.87
# 1000000000    28.59         61.69     95.96      77.87
# 2000000000    28.57         61.70     95.97      77.87
#
#
# Processing folder: parallel_reduction2a_benchmarks
# Files:  {1000000000: {'ncu_threaddiv': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1000000000/ncu_basic.txt', 'output': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1000000000/ncu_warp_efficiency.txt'}, 2000000000: {'ncu_threaddiv': 'parallel_reduction2a_benchmarks/parallel_reduction2a_2000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2a_benchmarks/parallel_reduction2a_2000000000/ncu_basic.txt', 'output': 'parallel_reduction2a_benchmarks/parallel_reduction2a_2000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction2a_benchmarks/parallel_reduction2a_2000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2a_benchmarks/parallel_reduction2a_2000000000/ncu_warp_efficiency.txt'}, 1024: {'ncu_threaddiv': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1024/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1024/ncu_basic.txt', 'output': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1024/output.txt', 'ncu_memory_usage': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1024/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1024/ncu_warp_efficiency.txt'}, 1000000: {'ncu_threaddiv': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1000000/ncu_basic.txt', 'output': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1000000/output.txt', 'ncu_memory_usage': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2a_benchmarks/parallel_reduction2a_1000000/ncu_warp_efficiency.txt'}}
# Size: 1024
# {'Input Size': 1024, 'cudaEventRecord': '27.5087', 'Duration': '5.25 usecond', 'DRAM mem': '7.42 Kbyte', 'L1 mem': '12.54 Kbyte', 'Warp exec %': '98.62', 'Warp avg threads': '31.56', 'Mem thrpt': '0.25', 'DRAM thrpt': '0.04', 'L1 thrpt': '14.58', 'L2 thrpt': '0.25', 'SM Throughput': '0.14', 'Occupancy': '48.47', 'Branch eff': '99.29'}
# Size: 1000000
# {'Input Size': 1000000, 'cudaEventRecord': '20.9161', 'Duration': '18.37 usecond', 'DRAM mem': '4.00 Mbyte', 'L1 mem': '12.25 Mbyte', 'Warp exec %': '98.62', 'Warp avg threads': '31.56', 'Mem thrpt': '10.77', 'DRAM thrpt': '10.77', 'L1 thrpt': '9.51', 'L2 thrpt': '20.37', 'SM Throughput': '37.20', 'Occupancy': '86.70', 'Branch eff': '99.29'}
# Size: 1000000000
# {'Input Size': 1000000000, 'cudaEventRecord': '31.7293', 'Duration': '14.05 msecond', 'DRAM mem': '4.00 Gbyte', 'L1 mem': '12.25 Gbyte', 'Warp exec %': '98.62', 'Warp avg threads': '31.56', 'Mem thrpt': '20.91', 'DRAM thrpt': '20.91', 'L1 thrpt': '9.84', 'L2 thrpt': '27.52', 'SM Throughput': '47.48', 'Occupancy': '90.60', 'Branch eff': '99.29'}
# Size: 2000000000
# {'Input Size': 2000000000, 'cudaEventRecord': '44.384', 'Duration': '28.11 msecond', 'DRAM mem': '8.00 Gbyte', 'L1 mem': '24.50 Gbyte', 'Warp exec %': '98.62', 'Warp avg threads': '31.56', 'Mem thrpt': '20.93', 'DRAM thrpt': '20.93', 'L1 thrpt': '9.83', 'L2 thrpt': '27.64', 'SM Throughput': '47.47', 'Occupancy': '90.60', 'Branch eff': '99.29'}
#            cudaEventRecord       Duration    DRAM mem       L1 mem  \
# Input Size
# 1024               27.5087   5.25 usecond  7.42 Kbyte  12.54 Kbyte
# 1000000            20.9161  18.37 usecond  4.00 Mbyte  12.25 Mbyte
# 1000000000         31.7293  14.05 msecond  4.00 Gbyte  12.25 Gbyte
# 2000000000          44.384  28.11 msecond  8.00 Gbyte  24.50 Gbyte
#
#            Warp exec % Warp avg threads Mem thrpt DRAM thrpt L1 thrpt  \
# Input Size
# 1024             98.62            31.56      0.25       0.04    14.58
# 1000000          98.62            31.56     10.77      10.77     9.51
# 1000000000       98.62            31.56     20.91      20.91     9.84
# 2000000000       98.62            31.56     20.93      20.93     9.83
#
#            L2 thrpt SM Throughput Occupancy Branch eff
# Input Size
# 1024           0.25          0.14     48.47      99.29
# 1000000       20.37         37.20     86.70      99.29
# 1000000000    27.52         47.48     90.60      99.29
# 2000000000    27.64         47.47     90.60      99.29
#
#
# Processing folder: parallel_reduction2b_benchmarks
# Files:  {2000000000: {'ncu_threaddiv': 'parallel_reduction2b_benchmarks/parallel_reduction2b_2000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2b_benchmarks/parallel_reduction2b_2000000000/ncu_basic.txt', 'output': 'parallel_reduction2b_benchmarks/parallel_reduction2b_2000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction2b_benchmarks/parallel_reduction2b_2000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2b_benchmarks/parallel_reduction2b_2000000000/ncu_warp_efficiency.txt'}, 1000000: {'ncu_threaddiv': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1000000/ncu_basic.txt', 'output': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1000000/output.txt', 'ncu_memory_usage': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1000000/ncu_warp_efficiency.txt'}, 1000000000: {'ncu_threaddiv': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1000000000/ncu_basic.txt', 'output': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1000000000/ncu_warp_efficiency.txt'}, 1024: {'ncu_threaddiv': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1024/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1024/ncu_basic.txt', 'output': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1024/output.txt', 'ncu_memory_usage': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1024/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2b_benchmarks/parallel_reduction2b_1024/ncu_warp_efficiency.txt'}}
# Size: 1024
# {'Input Size': 1024, 'cudaEventRecord': '167.855', 'Duration': '5.06 usecond', 'DRAM mem': '7.30 Kbyte', 'L1 mem': '4.13 Kbyte', 'Warp exec %': '99.87', 'Warp avg threads': '31.96', 'Mem thrpt': '0.40', 'DRAM thrpt': '0.04', 'L1 thrpt': '27.58', 'L2 thrpt': '0.40', 'SM Throughput': '0.17', 'Occupancy': '48.79', 'Branch eff': '100'}
# Size: 1000000
# {'Input Size': 1000000, 'cudaEventRecord': '19.0138', 'Duration': '18.50 usecond', 'DRAM mem': '4.00 Mbyte', 'L1 mem': '4.03 Mbyte', 'Warp exec %': '99.87', 'Warp avg threads': '31.96', 'Mem thrpt': '46.99', 'DRAM thrpt': '10.78', 'L1 thrpt': '56.61', 'L2 thrpt': '10.61', 'SM Throughput': '45.53', 'Occupancy': '88.49', 'Branch eff': '100'}
# Size: 1000000000
# {'Input Size': 1000000000, 'cudaEventRecord': '41.576', 'Duration': '13.69 msecond', 'DRAM mem': '4.00 Gbyte', 'L1 mem': '4.03 Gbyte', 'Warp exec %': '99.87', 'Warp avg threads': '31.96', 'Mem thrpt': '62.69', 'DRAM thrpt': '14.34', 'L1 thrpt': '62.70', 'L2 thrpt': '15.69', 'SM Throughput': '60.50', 'Occupancy': '91.35', 'Branch eff': '100'}
# Size: 2000000000
# {'Input Size': 2000000000, 'cudaEventRecord': '55.2548', 'Duration': '27.39 msecond', 'DRAM mem': '8.00 Gbyte', 'L1 mem': '8.06 Gbyte', 'Warp exec %': '99.87', 'Warp avg threads': '31.96', 'Mem thrpt': '62.70', 'DRAM thrpt': '14.34', 'L1 thrpt': '62.71', 'L2 thrpt': '15.71', 'SM Throughput': '60.51', 'Occupancy': '91.35', 'Branch eff': '100'}
#            cudaEventRecord       Duration    DRAM mem      L1 mem Warp exec %  \
# Input Size
# 1024               167.855   5.06 usecond  7.30 Kbyte  4.13 Kbyte       99.87
# 1000000            19.0138  18.50 usecond  4.00 Mbyte  4.03 Mbyte       99.87
# 1000000000          41.576  13.69 msecond  4.00 Gbyte  4.03 Gbyte       99.87
# 2000000000         55.2548  27.39 msecond  8.00 Gbyte  8.06 Gbyte       99.87
#
#            Warp avg threads Mem thrpt DRAM thrpt L1 thrpt L2 thrpt  \
# Input Size
# 1024                  31.96      0.40       0.04    27.58     0.40
# 1000000               31.96     46.99      10.78    56.61    10.61
# 1000000000            31.96     62.69      14.34    62.70    15.69
# 2000000000            31.96     62.70      14.34    62.71    15.71
#
#            SM Throughput Occupancy Branch eff
# Input Size
# 1024                0.17     48.79        100
# 1000000            45.53     88.49        100
# 1000000000         60.50     91.35        100
# 2000000000         60.51     91.35        100
#
#
# Processing folder: parallel_reduction2c_benchmarks
# Files:  {1024: {'ncu_threaddiv': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1024/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1024/ncu_basic.txt', 'output': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1024/output.txt', 'ncu_memory_usage': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1024/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1024/ncu_warp_efficiency.txt'}, 1000000: {'ncu_threaddiv': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1000000/ncu_basic.txt', 'output': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1000000/output.txt', 'ncu_memory_usage': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1000000/ncu_warp_efficiency.txt'}, 2000000000: {'ncu_threaddiv': 'parallel_reduction2c_benchmarks/parallel_reduction2c_2000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2c_benchmarks/parallel_reduction2c_2000000000/ncu_basic.txt', 'output': 'parallel_reduction2c_benchmarks/parallel_reduction2c_2000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction2c_benchmarks/parallel_reduction2c_2000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2c_benchmarks/parallel_reduction2c_2000000000/ncu_warp_efficiency.txt'}, 1000000000: {'ncu_threaddiv': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1000000000/ncu_basic.txt', 'output': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction2c_benchmarks/parallel_reduction2c_1000000000/ncu_warp_efficiency.txt'}}
# Size: 1024
# {'Input Size': 1024, 'cudaEventRecord': '31.8566', 'Duration': '5.28 usecond', 'DRAM mem': '7.55 Kbyte', 'L1 mem': '4.13 Kbyte', 'Warp exec %': '99.88', 'Warp avg threads': '31.96', 'Mem thrpt': '0.23', 'DRAM thrpt': '0.04', 'L1 thrpt': '29.58', 'L2 thrpt': '0.23', 'SM Throughput': '0.17', 'Occupancy': '48.74', 'Branch eff': '100'}
# Size: 1000000
# {'Input Size': 1000000, 'cudaEventRecord': '33.7327', 'Duration': '12.03 usecond', 'DRAM mem': '4.00 Mbyte', 'L1 mem': '4.02 Mbyte', 'Warp exec %': '99.88', 'Warp avg threads': '31.96', 'Mem thrpt': '37.19', 'DRAM thrpt': '16.50', 'L1 thrpt': '49.66', 'L2 thrpt': '15.81', 'SM Throughput': '36.03', 'Occupancy': '87.71', 'Branch eff': '100'}
# Size: 1000000000
# {'Input Size': 1000000000, 'cudaEventRecord': '26.5822', 'Duration': '7.16 msecond', 'DRAM mem': '4.00 Gbyte', 'L1 mem': '4.02 Gbyte', 'Warp exec %': '99.88', 'Warp avg threads': '31.96', 'Mem thrpt': '61.64', 'DRAM thrpt': '27.42', 'L1 thrpt': '61.67', 'L2 thrpt': '29.59', 'SM Throughput': '59.60', 'Occupancy': '91.66', 'Branch eff': '100'}
# Size: 2000000000
# {'Input Size': 2000000000, 'cudaEventRecord': '34.4352', 'Duration': '14.31 msecond', 'DRAM mem': '8.00 Gbyte', 'L1 mem': '8.03 Gbyte', 'Warp exec %': '99.88', 'Warp avg threads': '31.96', 'Mem thrpt': '61.66', 'DRAM thrpt': '27.42', 'L1 thrpt': '61.67', 'L2 thrpt': '29.50', 'SM Throughput': '59.62', 'Occupancy': '91.66', 'Branch eff': '100'}
#            cudaEventRecord       Duration    DRAM mem      L1 mem Warp exec %  \
# Input Size
# 1024               31.8566   5.28 usecond  7.55 Kbyte  4.13 Kbyte       99.88
# 1000000            33.7327  12.03 usecond  4.00 Mbyte  4.02 Mbyte       99.88
# 1000000000         26.5822   7.16 msecond  4.00 Gbyte  4.02 Gbyte       99.88
# 2000000000         34.4352  14.31 msecond  8.00 Gbyte  8.03 Gbyte       99.88
#
#            Warp avg threads Mem thrpt DRAM thrpt L1 thrpt L2 thrpt  \
# Input Size
# 1024                  31.96      0.23       0.04    29.58     0.23
# 1000000               31.96     37.19      16.50    49.66    15.81
# 1000000000            31.96     61.64      27.42    61.67    29.59
# 2000000000            31.96     61.66      27.42    61.67    29.50
#
#            SM Throughput Occupancy Branch eff
# Input Size
# 1024                0.17     48.74        100
# 1000000            36.03     87.71        100
# 1000000000         59.60     91.66        100
# 2000000000         59.62     91.66        100
#
#
# Processing folder: parallel_reduction3a_benchmarks
# Files:  {2000000000: {'ncu_threaddiv': 'parallel_reduction3a_benchmarks/parallel_reduction3a_2000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction3a_benchmarks/parallel_reduction3a_2000000000/ncu_basic.txt', 'output': 'parallel_reduction3a_benchmarks/parallel_reduction3a_2000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction3a_benchmarks/parallel_reduction3a_2000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction3a_benchmarks/parallel_reduction3a_2000000000/ncu_warp_efficiency.txt'}, 1000000: {'ncu_threaddiv': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1000000/ncu_basic.txt', 'output': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1000000/output.txt', 'ncu_memory_usage': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1000000/ncu_warp_efficiency.txt'}, 1000000000: {'ncu_threaddiv': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1000000000/ncu_basic.txt', 'output': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1000000000/ncu_warp_efficiency.txt'}, 1024: {'ncu_threaddiv': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1024/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1024/ncu_basic.txt', 'output': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1024/output.txt', 'ncu_memory_usage': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1024/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction3a_benchmarks/parallel_reduction3a_1024/ncu_warp_efficiency.txt'}}
# Size: 1024
# {'Input Size': 1024, 'cudaEventRecord': '37.2705', 'Duration': '4.06 usecond', 'DRAM mem': '7.81 Kbyte', 'L1 mem': '4.13 Kbyte', 'Warp exec %': '99.80', 'Warp avg threads': '31.94', 'Mem thrpt': '0.30', 'DRAM thrpt': '0.05', 'L1 thrpt': '20.28', 'L2 thrpt': '0.30', 'SM Throughput': '0.13', 'Occupancy': '44.61', 'Branch eff': '100'}
# Size: 1000000
# {'Input Size': 1000000, 'cudaEventRecord': '22.7144', 'Duration': '9.60 usecond', 'DRAM mem': '4.00 Mbyte', 'L1 mem': '4.02 Mbyte', 'Warp exec %': '99.80', 'Warp avg threads': '31.94', 'Mem thrpt': '22.46', 'DRAM thrpt': '20.35', 'L1 thrpt': '33.01', 'L2 thrpt': '19.00', 'SM Throughput': '25.62', 'Occupancy': '79.40', 'Branch eff': '100'}
# Size: 1000000000
# {'Input Size': 1000000000, 'cudaEventRecord': '24.3433', 'Duration': '4.98 msecond', 'DRAM mem': '4.00 Gbyte', 'L1 mem': '4.02 Gbyte', 'Warp exec %': '99.80', 'Warp avg threads': '31.94', 'Mem thrpt': '43.86', 'DRAM thrpt': '39.43', 'L1 thrpt': '43.89', 'L2 thrpt': '41.53', 'SM Throughput': '47.15', 'Occupancy': '79.24', 'Branch eff': '100'}
# Size: 2000000000
# {'Input Size': 2000000000, 'cudaEventRecord': '30.1529', 'Duration': '9.95 msecond', 'DRAM mem': '8.00 Gbyte', 'L1 mem': '8.03 Gbyte', 'Warp exec %': '99.80', 'Warp avg threads': '31.94', 'Mem thrpt': '43.89', 'DRAM thrpt': '39.45', 'L1 thrpt': '43.90', 'L2 thrpt': '41.43', 'SM Throughput': '47.18', 'Occupancy': '79.24', 'Branch eff': '100'}
#            cudaEventRecord      Duration    DRAM mem      L1 mem Warp exec %  \
# Input Size
# 1024               37.2705  4.06 usecond  7.81 Kbyte  4.13 Kbyte       99.80
# 1000000            22.7144  9.60 usecond  4.00 Mbyte  4.02 Mbyte       99.80
# 1000000000         24.3433  4.98 msecond  4.00 Gbyte  4.02 Gbyte       99.80
# 2000000000         30.1529  9.95 msecond  8.00 Gbyte  8.03 Gbyte       99.80
#
#            Warp avg threads Mem thrpt DRAM thrpt L1 thrpt L2 thrpt  \
# Input Size
# 1024                  31.94      0.30       0.05    20.28     0.30
# 1000000               31.94     22.46      20.35    33.01    19.00
# 1000000000            31.94     43.86      39.43    43.89    41.53
# 2000000000            31.94     43.89      39.45    43.90    41.43
#
#            SM Throughput Occupancy Branch eff
# Input Size
# 1024                0.13     44.61        100
# 1000000            25.62     79.40        100
# 1000000000         47.15     79.24        100
# 2000000000         47.18     79.24        100
#
#
# Processing folder: parallel_reduction3b_benchmarks
# Files:  {1000000: {'ncu_threaddiv': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1000000/ncu_basic.txt', 'output': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1000000/output.txt', 'ncu_memory_usage': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1000000/ncu_warp_efficiency.txt'}, 2000000000: {'ncu_threaddiv': 'parallel_reduction3b_benchmarks/parallel_reduction3b_2000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction3b_benchmarks/parallel_reduction3b_2000000000/ncu_basic.txt', 'output': 'parallel_reduction3b_benchmarks/parallel_reduction3b_2000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction3b_benchmarks/parallel_reduction3b_2000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction3b_benchmarks/parallel_reduction3b_2000000000/ncu_warp_efficiency.txt'}, 1000000000: {'ncu_threaddiv': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1000000000/ncu_basic.txt', 'output': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1000000000/ncu_warp_efficiency.txt'}, 1024: {'ncu_threaddiv': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1024/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1024/ncu_basic.txt', 'output': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1024/output.txt', 'ncu_memory_usage': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1024/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction3b_benchmarks/parallel_reduction3b_1024/ncu_warp_efficiency.txt'}}
# Size: 1024
# {'Input Size': 1024, 'cudaEventRecord': '28.417', 'Duration': '4.22 usecond', 'DRAM mem': '8.96 Kbyte', 'L1 mem': '4.13 Kbyte', 'Warp exec %': '99.80', 'Warp avg threads': '31.94', 'Mem thrpt': '0.29', 'DRAM thrpt': '0.05', 'L1 thrpt': '19.37', 'L2 thrpt': '0.29', 'SM Throughput': '0.13', 'Occupancy': '43.13', 'Branch eff': '100'}
# Size: 1000000
# {'Input Size': 1000000, 'cudaEventRecord': '20.0971', 'Duration': '10.02 usecond', 'DRAM mem': '4.00 Mbyte', 'L1 mem': '4.02 Mbyte', 'Warp exec %': '99.80', 'Warp avg threads': '31.94', 'Mem thrpt': '22.67', 'DRAM thrpt': '20.30', 'L1 thrpt': '31.55', 'L2 thrpt': '20.59', 'SM Throughput': '25.63', 'Occupancy': '76.51', 'Branch eff': '100'}
# Size: 1000000000
# {'Input Size': 1000000000, 'cudaEventRecord': '25.0687', 'Duration': '5.30 msecond', 'DRAM mem': '4.00 Gbyte', 'L1 mem': '4.02 Gbyte', 'Warp exec %': '99.80', 'Warp avg threads': '31.94', 'Mem thrpt': '41.56', 'DRAM thrpt': '37.04', 'L1 thrpt': '41.59', 'L2 thrpt': '39.06', 'SM Throughput': '44.46', 'Occupancy': '75.31', 'Branch eff': '100'}
# Size: 2000000000
# {'Input Size': 2000000000, 'cudaEventRecord': '29.4488', 'Duration': '10.59 msecond', 'DRAM mem': '8.00 Gbyte', 'L1 mem': '8.03 Gbyte', 'Warp exec %': '99.80', 'Warp avg threads': '31.94', 'Mem thrpt': '41.58', 'DRAM thrpt': '37.05', 'L1 thrpt': '41.60', 'L2 thrpt': '39.12', 'SM Throughput': '44.48', 'Occupancy': '75.31', 'Branch eff': '100'}
#            cudaEventRecord       Duration    DRAM mem      L1 mem Warp exec %  \
# Input Size
# 1024                28.417   4.22 usecond  8.96 Kbyte  4.13 Kbyte       99.80
# 1000000            20.0971  10.02 usecond  4.00 Mbyte  4.02 Mbyte       99.80
# 1000000000         25.0687   5.30 msecond  4.00 Gbyte  4.02 Gbyte       99.80
# 2000000000         29.4488  10.59 msecond  8.00 Gbyte  8.03 Gbyte       99.80
#
#            Warp avg threads Mem thrpt DRAM thrpt L1 thrpt L2 thrpt  \
# Input Size
# 1024                  31.94      0.29       0.05    19.37     0.29
# 1000000               31.94     22.67      20.30    31.55    20.59
# 1000000000            31.94     41.56      37.04    41.59    39.06
# 2000000000            31.94     41.58      37.05    41.60    39.12
#
#            SM Throughput Occupancy Branch eff
# Input Size
# 1024                0.13     43.13        100
# 1000000            25.63     76.51        100
# 1000000000         44.46     75.31        100
# 2000000000         44.48     75.31        100
#
#
# Processing folder: parallel_reduction4_benchmarks
# Files:  {1024: {'ncu_threaddiv': 'parallel_reduction4_benchmarks/parallel_reduction4_1024/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction4_benchmarks/parallel_reduction4_1024/ncu_basic.txt', 'output': 'parallel_reduction4_benchmarks/parallel_reduction4_1024/output.txt', 'ncu_memory_usage': 'parallel_reduction4_benchmarks/parallel_reduction4_1024/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction4_benchmarks/parallel_reduction4_1024/ncu_warp_efficiency.txt'}, 2000000000: {'ncu_threaddiv': 'parallel_reduction4_benchmarks/parallel_reduction4_2000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction4_benchmarks/parallel_reduction4_2000000000/ncu_basic.txt', 'output': 'parallel_reduction4_benchmarks/parallel_reduction4_2000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction4_benchmarks/parallel_reduction4_2000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction4_benchmarks/parallel_reduction4_2000000000/ncu_warp_efficiency.txt'}, 1000000: {'ncu_threaddiv': 'parallel_reduction4_benchmarks/parallel_reduction4_1000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction4_benchmarks/parallel_reduction4_1000000/ncu_basic.txt', 'output': 'parallel_reduction4_benchmarks/parallel_reduction4_1000000/output.txt', 'ncu_memory_usage': 'parallel_reduction4_benchmarks/parallel_reduction4_1000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction4_benchmarks/parallel_reduction4_1000000/ncu_warp_efficiency.txt'}, 1000000000: {'ncu_threaddiv': 'parallel_reduction4_benchmarks/parallel_reduction4_1000000000/ncu_threaddiv.txt', 'ncu_basic': 'parallel_reduction4_benchmarks/parallel_reduction4_1000000000/ncu_basic.txt', 'output': 'parallel_reduction4_benchmarks/parallel_reduction4_1000000000/output.txt', 'ncu_memory_usage': 'parallel_reduction4_benchmarks/parallel_reduction4_1000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'parallel_reduction4_benchmarks/parallel_reduction4_1000000000/ncu_warp_efficiency.txt'}}
# Size: 1024
# {'Input Size': 1024, 'cudaEventRecord': '26.2298', 'Duration': '4.19 usecond', 'DRAM mem': '8.83 Kbyte', 'L1 mem': '4.13 Kbyte', 'Warp exec %': '99.70', 'Warp avg threads': '31.90', 'Mem thrpt': '0.29', 'DRAM thrpt': '0.05', 'L1 thrpt': '18.13', 'L2 thrpt': '0.29', 'SM Throughput': '0.10', 'Occupancy': '45.23', 'Branch eff': '100'}
# Size: 1000000
# {'Input Size': 1000000, 'cudaEventRecord': '20.8731', 'Duration': '9.15 usecond', 'DRAM mem': '4.00 Mbyte', 'L1 mem': '4.02 Mbyte', 'Warp exec %': '99.70', 'Warp avg threads': '31.90', 'Mem thrpt': '24.27', 'DRAM thrpt': '22.20', 'L1 thrpt': '35.09', 'L2 thrpt': '21.84', 'SM Throughput': '23.51', 'Occupancy': '79.06', 'Branch eff': '100'}
# Size: 1000000000
# {'Input Size': 1000000000, 'cudaEventRecord': '28.9318', 'Duration': '4.41 msecond', 'DRAM mem': '4.00 Gbyte', 'L1 mem': '4.02 Gbyte', 'Warp exec %': '99.70', 'Warp avg threads': '31.90', 'Mem thrpt': '49.18', 'DRAM thrpt': '44.47', 'L1 thrpt': '49.21', 'L2 thrpt': '46.53', 'SM Throughput': '46.77', 'Occupancy': '76.23', 'Branch eff': '100'}
# Size: 2000000000
# {'Input Size': 2000000000, 'cudaEventRecord': '30.7977', 'Duration': '8.82 msecond', 'DRAM mem': '8.00 Gbyte', 'L1 mem': '8.03 Gbyte', 'Warp exec %': '99.70', 'Warp avg threads': '31.90', 'Mem thrpt': '49.21', 'DRAM thrpt': '44.50', 'L1 thrpt': '49.22', 'L2 thrpt': '46.51', 'SM Throughput': '46.80', 'Occupancy': '76.24', 'Branch eff': '100'}
#            cudaEventRecord      Duration    DRAM mem      L1 mem Warp exec %  \
# Input Size
# 1024               26.2298  4.19 usecond  8.83 Kbyte  4.13 Kbyte       99.70
# 1000000            20.8731  9.15 usecond  4.00 Mbyte  4.02 Mbyte       99.70
# 1000000000         28.9318  4.41 msecond  4.00 Gbyte  4.02 Gbyte       99.70
# 2000000000         30.7977  8.82 msecond  8.00 Gbyte  8.03 Gbyte       99.70
#
#            Warp avg threads Mem thrpt DRAM thrpt L1 thrpt L2 thrpt  \
# Input Size
# 1024                  31.90      0.29       0.05    18.13     0.29
# 1000000               31.90     24.27      22.20    35.09    21.84
# 1000000000            31.90     49.18      44.47    49.21    46.53
# 2000000000            31.90     49.21      44.50    49.22    46.51
#
#            SM Throughput Occupancy Branch eff
# Input Size
# 1024                0.10     45.23        100
# 1000000            23.51     79.06        100
# 1000000000         46.77     76.23        100
# 2000000000         46.80     76.24        100
#
#
# Processing folder: llm_based_gpt4o_mini_benchmarks
# Files:  {1000000000: {'ncu_threaddiv': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1000000000/ncu_threaddiv.txt', 'ncu_basic': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1000000000/ncu_basic.txt', 'output': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1000000000/output.txt', 'ncu_memory_usage': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1000000000/ncu_warp_efficiency.txt'}, 1000000: {'ncu_threaddiv': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1000000/ncu_threaddiv.txt', 'ncu_basic': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1000000/ncu_basic.txt', 'output': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1000000/output.txt', 'ncu_memory_usage': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1000000/ncu_warp_efficiency.txt'}, 2000000000: {'ncu_threaddiv': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_2000000000/ncu_threaddiv.txt', 'ncu_basic': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_2000000000/ncu_basic.txt', 'output': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_2000000000/output.txt', 'ncu_memory_usage': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_2000000000/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_2000000000/ncu_warp_efficiency.txt'}, 1024: {'ncu_threaddiv': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1024/ncu_threaddiv.txt', 'ncu_basic': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1024/ncu_basic.txt', 'output': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1024/output.txt', 'ncu_memory_usage': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1024/ncu_memory_usage.txt', 'ncu_warp_efficiency': 'llm_based_gpt4o_mini_benchmarks/llm_based_gpt4o_mini_1024/ncu_warp_efficiency.txt'}}
# Size: 1024
# {'Input Size': 1024, 'cudaEventRecord': '74.4069', 'Duration': '4 usecond', 'DRAM mem': '7.30 Kbyte', 'L1 mem': '4.22 Kbyte', 'Warp exec %': '99.40', 'Warp avg threads': '31.81', 'Mem thrpt': '0.30', 'DRAM thrpt': '0.06', 'L1 thrpt': '10.51', 'L2 thrpt': '0.30', 'SM Throughput': '0.19', 'Occupancy': '12.22', 'Branch eff': '100'}
# Size: 1000000
# {'Input Size': 1000000, 'cudaEventRecord': '19.8638', 'Duration': '13.79 usecond', 'DRAM mem': '4.00 Mbyte', 'L1 mem': '4.13 Mbyte', 'Warp exec %': '99.40', 'Warp avg threads': '31.81', 'Mem thrpt': '58.77', 'DRAM thrpt': '14.35', 'L1 thrpt': '71.20', 'L2 thrpt': '15.03', 'SM Throughput': '52.35', 'Occupancy': '82.36', 'Branch eff': '100'}
# Size: 1000000000
# {'Input Size': 1000000000, 'cudaEventRecord': '33.4227', 'Duration': '9.34 msecond', 'DRAM mem': '4.00 Gbyte', 'L1 mem': '4.12 Gbyte', 'Warp exec %': '99.40', 'Warp avg threads': '31.81', 'Mem thrpt': '85.38', 'DRAM thrpt': '21.08', 'L1 thrpt': '85.41', 'L2 thrpt': '23.76', 'SM Throughput': '75.81', 'Occupancy': '88.36', 'Branch eff': '100'}
# Size: 2000000000
# {'Input Size': 2000000000, 'cudaEventRecord': '38.7392', 'Duration': '18.68 msecond', 'DRAM mem': '8.00 Gbyte', 'L1 mem': '8.25 Gbyte', 'Warp exec %': '99.40', 'Warp avg threads': '31.81', 'Mem thrpt': '85.40', 'DRAM thrpt': '21.09', 'L1 thrpt': '85.42', 'L2 thrpt': '23.78', 'SM Throughput': '75.82', 'Occupancy': '88.36', 'Branch eff': '100'}
#            cudaEventRecord       Duration    DRAM mem      L1 mem Warp exec %  \
# Input Size
# 1024               74.4069      4 usecond  7.30 Kbyte  4.22 Kbyte       99.40
# 1000000            19.8638  13.79 usecond  4.00 Mbyte  4.13 Mbyte       99.40
# 1000000000         33.4227   9.34 msecond  4.00 Gbyte  4.12 Gbyte       99.40
# 2000000000         38.7392  18.68 msecond  8.00 Gbyte  8.25 Gbyte       99.40
#
#            Warp avg threads Mem thrpt DRAM thrpt L1 thrpt L2 thrpt  \
# Input Size
# 1024                  31.81      0.30       0.06    10.51     0.30
# 1000000               31.81     58.77      14.35    71.20    15.03
# 1000000000            31.81     85.38      21.08    85.41    23.76
# 2000000000            31.81     85.40      21.09    85.42    23.78
#
#            SM Throughput Occupancy Branch eff
# Input Size
# 1024                0.19     12.22        100
# 1000000            52.35     82.36        100
# 1000000000         75.81     88.36        100
# 2000000000         75.82     88.36        100
